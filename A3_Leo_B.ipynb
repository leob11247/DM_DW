# %%
import pandas as pd
from mlxtend.frequent_patterns import fpgrowth, association_rules
from mlxtend.preprocessing import TransactionEncoder
from IPython.display import display

#This is for association rule assignment
#Leo Baltazar

Movies_Data = pd.read_csv("/Users/leobaltazar/Desktop/Data Mining/Movies.tsv", delimiter='\t')
Ratings_Data = pd.read_csv("/Users/leobaltazar/Desktop/Data Mining/Ratings.tsv", delimiter='\t')

Movies_Data["genres"] = Movies_Data["genres"].apply(lambda x: x.split("|"))

Ratings_Data["rating"] = pd.to_numeric(Ratings_Data["rating"]).astype(int)
high_ratings = Ratings_Data[Ratings_Data["rating"] >= 4]

merged_data = pd.merge(high_ratings, Movies_Data, on="movieId", how="inner")

transactions = merged_data.groupby("userId")["genres"].apply(lambda x: list(set(sum(x, []))))
transactions = transactions.tolist()

encoder = TransactionEncoder()
encoded_data = encoder.fit(transactions).transform(transactions)
df_transactions = pd.DataFrame(encoded_data, columns=encoder.columns_)
print(len(df_transactions))

frequent_itemsets = fpgrowth(df_transactions, min_support=0.6, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

display(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].sort_values("lift", ascending=False).head(20))
# Out:
# 91
#                                               antecedents  \
# 251555      (Animation, Romance, Drama, Thriller, Action)
# 246894            (Action, Adventure, Animation, Romance)
# 252123               (Comedy, Action, Animation, Romance)
# 255289                          (Sci-Fi, Crime, Children)
# 241483               (Comedy, Action, Animation, Romance)
# 241480                  (Comedy, Sci-Fi, Crime, Children)
# 252154               (Sci-Fi, Adventure, Crime, Children)
# 255315                       (Action, Animation, Romance)
# 247962                       (Action, Animation, Romance)
# 252173                   (Sci-Fi, Drama, Crime, Children)
# 252178            (Action, Adventure, Animation, Romance)
# 242150                          (Sci-Fi, Crime, Children)
# 242154                       (Action, Animation, Romance)
# 252197                (Action, Drama, Animation, Romance)
# 247708                       (Action, Animation, Romance)
# 252104                  (Comedy, Sci-Fi, Crime, Children)
# 252258                          (Sci-Fi, Crime, Children)
# 253054  (Adventure, Animation, Romance, Thriller, Action)
# 247689                          (Sci-Fi, Crime, Children)
# 252277                       (Action, Animation, Romance)
#
#                                               consequents   support  \
# 251555                  (Comedy, Sci-Fi, Crime, Children)  0.615385
# 246894                  (Comedy, Sci-Fi, Crime, Children)  0.615385
# 252123        (Sci-Fi, Adventure, Drama, Crime, Children)  0.615385
# 255289  (Comedy, Adventure, Animation, Romance, Drama,...  0.615385
# 241483                          (Sci-Fi, Crime, Children)  0.615385
# 241480                       (Action, Animation, Romance)  0.615385
# 252154        (Comedy, Animation, Romance, Drama, Action)  0.615385
# 255315  (Comedy, Sci-Fi, Adventure, Drama, Thriller, C...  0.615385
# 247962     (Sci-Fi, Adventure, Thriller, Crime, Children)  0.615385
# 252173    (Comedy, Adventure, Animation, Romance, Action)  0.615385
# 252178           (Comedy, Sci-Fi, Drama, Crime, Children)  0.615385
# 242150             (Thriller, Action, Animation, Romance)  0.615385
# 242154                (Sci-Fi, Children, Crime, Thriller)  0.615385
# 252197       (Comedy, Sci-Fi, Adventure, Crime, Children)  0.615385
# 247708        (Sci-Fi, Adventure, Drama, Crime, Children)  0.615385
# 252104     (Adventure, Animation, Romance, Drama, Action)  0.615385
# 252258  (Comedy, Adventure, Animation, Romance, Drama,...  0.615385
# 253054                   (Sci-Fi, Drama, Crime, Children)  0.615385
# 247689     (Adventure, Animation, Romance, Drama, Action)  0.615385
# 252277  (Comedy, Sci-Fi, Adventure, Drama, Crime, Chil...  0.615385
#
#         confidence      lift
# 251555    0.949153  1.393111
# 246894    0.949153  1.393111
# 252123    0.949153  1.393111
# 255289    0.903226  1.393111
# 241483    0.949153  1.393111
# 241480    0.903226  1.393111
# 252154    0.903226  1.393111
# 255315    0.949153  1.393111
# 247962    0.949153  1.393111
# 252173    0.903226  1.393111
# 252178    0.949153  1.393111
# 242150    0.903226  1.393111
# 242154    0.949153  1.393111
# 252197    0.949153  1.393111
# 247708    0.949153  1.393111
# 252104    0.903226  1.393111
# 252258    0.903226  1.393111
# 253054    0.949153  1.393111
# 247689    0.903226  1.393111
# 252277    0.949153  1.393111
